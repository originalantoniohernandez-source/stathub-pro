# %% [markdown]
# <a href="https://colab.research.google.com/github/originalantoniohernandez-source/stathub-pro/blob/main/Word_Embeddings_LLM_Lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ======================================================
# 1️⃣ Install dependencies
# ======================================================
# !pip install -q gensim scikit-learn plotly ipywidgets

# ======================================================
# 2️⃣ Load lightweight embedding model
# ======================================================
from gensim import downloader
print("⏳ Loading GloVe 100D model...")
model = downloader.load("glove-wiki-gigaword-100")
print(f"✅ Loaded {len(model.index_to_key):,} words with {model.vector_size}-D vectors.\n")

# ======================================================
# 3️⃣ Define semantic groups
# ======================================================
categories = {
    "Royalty / Gender": ["king", "queen", "man", "woman", "prince", "princess", "boy", "girl"],
    "Countries / Capitals": ["france", "paris", "italy", "rome", "germany", "berlin", "spain", "madrid"],
    "Animals / Habitats": ["dog", "wolf", "cat", "lion", "tiger", "forest", "house", "zoo"],
    "Technology": ["computer", "internet", "ai", "robot", "software", "hardware", "data", "science"],
}

# Gather vectors
words, vectors, labels = [], [], []
for cat, wordlist in categories.items():
    for w in wordlist:
        if w in model.key_to_index:
            words.append(w)
            vectors.append(model[w])
            labels.append(cat)

# ======================================================
# 4️⃣ Reduce to 3D using PCA
# ======================================================
from sklearn.decomposition import PCA
import numpy as np
pca = PCA(n_components=3)
reduced = pca.fit_transform(vectors)

# ======================================================
# 5️⃣ Interactive 3D Visualization with Dropdown
# ======================================================
import plotly.graph_objects as go

color_map = {
    "Royalty / Gender": "purple",
    "Countries / Capitals": "green",
    "Animals / Habitats": "orange",
    "Technology": "blue"
}

traces = []
for cat in categories.keys():
    indices = [i for i, lbl in enumerate(labels) if lbl == cat]
    trace = go.Scatter3d(
        x=reduced[indices,0],
        y=reduced[indices,1],
        z=reduced[indices,2],
        mode='markers+text',
        text=[words[i] for i in indices],
        textposition='top center',
        marker=dict(size=6, color=color_map[cat], opacity=0.8),
        name=cat,
        visible=True if cat == "Royalty / Gender" else False
    )
    traces.append(trace)

buttons = []
for i, cat in enumerate(categories.keys()):
    visible = [False]*len(categories)
    visible[i] = True
    buttons.append(dict(label=cat, method="update", args=[{"visible": visible}]))

buttons.append(dict(label="Show All", method="update", args=[{"visible": [True]*len(categories)}]))

fig = go.Figure(data=traces)
fig.update_layout(
    title="🌐 3D Word Embeddings Visualization (with Category Dropdown)",
    scene=dict(xaxis_title="PC1", yaxis_title="PC2", zaxis_title="PC3"),
    updatemenus=[dict(active=0, buttons=buttons, x=1.15, y=0.9)],
    height=700
)
fig.show()

# ======================================================
# 6️⃣ Analogy Demonstrations
# ======================================================
print("\n🧩 Analogy Tests:")
tests = [
    ("king", "man", "woman"),
    ("paris", "france", "italy"),
    ("dog", "puppy", "kitten"),
    ("computer", "software", "hardware"),
]
for pos1, neg, pos2 in tests:
    try:
        result = model.most_similar(positive=[pos1, pos2], negative=[neg], topn=3)
        print(f"{pos1} - {neg} + {pos2} ≈ {result[0][0]} ({result[0][1]:.3f})")
    except KeyError:
        print(f"⚠️ One of the words in '{pos1}, {neg}, {pos2}' is missing from the model.")

# ======================================================
# 7️⃣ Interactive Cosine Similarity Explorer
# ======================================================
from ipywidgets import interact, Text, VBox, HTML

def similarity_explorer(word1, word2):
    word1, word2 = word1.lower().strip(), word2.lower().strip()
    if word1 in model.key_to_index and word2 in model.key_to_index:
        sim = model.similarity(word1, word2)
        print(f"\n🔍 Cosine similarity between '{word1}' and '{word2}': {sim:.4f}")
        if sim > 0.7:
            print("🟢 Very similar meanings.")
        elif sim > 0.4:
            print("🟡 Somewhat related.")
        else:
            print("🔴 Meanings are quite different.")
    else:
        print("⚠️ One or both words not found in vocabulary.")

print("\n💬 Type any two words to explore their semantic similarity:")
interact(similarity_explorer, word1=Text(value='king'), word2=Text(value='queen'));
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 40.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 31.0 MB/s eta 0:00:00
# ⏳ Loading GloVe 100D model...
# [==================================================] 100.0% 128.1/128.1MB downloaded
# ✅ Loaded 400,000 words with 100-D vectors.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0b947d5b-573f-4beb-b5d0-3219c1a05580" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0b947d5b-573f-4beb-b5d0-3219c1a05580")) {                    Plotly.newPlot(                        "0b947d5b-573f-4beb-b5d0-3219c1a05580",                        [{"marker":{"color":"purple","opacity":0.8,"size":6},"mode":"markers+text","name":"Royalty \u002f Gender","text":["king","queen","man","woman","prince","princess","boy","girl"],"textposition":"top center","visible":true,"x":[0.7623433737586802,1.0119859741995987,-0.4409769481775333,-0.45082080242695594,1.547054859629598,0.99873442022814,-1.4225373240405914,-1.0697551065430375],"y":[1.947244253919563,2.4776124877053167,1.5568249367680806,2.066623750288221,2.286883838499598,2.781960261193348,2.1428834078829913,2.5778232234396294],"z":[-2.143489302054554,-2.271420852309689,-0.6069299215855131,-1.2842462492803077,-1.9926837366115642,-2.2336336753685053,-0.784654039611349,-1.1547068861672052],"type":"scatter3d"},{"marker":{"color":"green","opacity":0.8,"size":6},"mode":"markers+text","name":"Countries \u002f Capitals","text":["france","paris","italy","rome","germany","berlin","spain","madrid"],"textposition":"top center","visible":false,"x":[3.950532142479002,3.304377429346015,3.686991462327194,3.061035016251589,3.1808681348024126,2.651670881962311,3.603726439400279,3.3364333306249643],"y":[-1.0087510556592294,-0.5614609399347211,-1.6597490238751567,-0.9714556769742039,-2.1285695314439357,-1.1405178062918382,-1.1138339008682048,-1.4925254326140782],"z":[0.10133226835541898,-0.0025479244853856228,0.04200181261836758,0.014459390883462167,0.986074358672315,1.3354828538066505,0.29707196148229975,1.1299675842633026],"type":"scatter3d"},{"marker":{"color":"orange","opacity":0.8,"size":6},"mode":"markers+text","name":"Animals \u002f Habitats","text":["dog","wolf","cat","lion","tiger","forest","house","zoo"],"textposition":"top center","visible":false,"x":[-1.8855100845827095,-1.3253496773046254,-1.942225373571558,-0.6391502843765391,-1.7362017472742142,-1.0139920054839122,-0.22164429474445543,-1.2924270226567338],"y":[1.9163879418435648,1.0190202577400036,1.8943257073813147,2.3813475401653563,1.4197080818626775,0.2093298868506958,0.3990298701571684,1.3209939453529846],"z":[1.2753226725237876,1.8690359546899837,1.1804757352139053,1.3091796581568849,1.913327248984489,2.8110567608584933,-0.5040394639687352,2.9477882000280036],"type":"scatter3d"},{"marker":{"color":"blue","opacity":0.8,"size":6},"mode":"markers+text","name":"Technology","text":["computer","internet","ai","robot","software","hardware","data","science"],"textposition":"top center","visible":false,"x":[-3.1822663257076838,-1.8757899236262587,-1.0824655538621764,-2.46653552743813,-3.153460428988459,-2.5796474800408054,-2.0737498923211537,-1.2412476618422528],"y":[-3.4595291417391487,-2.9119667512528697,0.06215039069876346,0.2595357570098565,-3.863735456029289,-2.887863868294219,-3.876433648123831,-1.6432933056584056],"z":[-1.3072740667664808,-2.0376519064721617,0.5027512514753422,0.6399920452788219,-1.1160386009545178,-0.8598106592474712,-0.18471871963279404,0.12852624722470402],"type":"scatter3d"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"hi ...
# 🧩 Analogy Tests:
# king - man + woman ≈ queen (0.770)
# paris - france + italy ≈ rome (0.819)
# dog - puppy + kitten ≈ cat (0.694)
# computer - software + hardware ≈ computers (0.787)
#
# 💬 Type any two words to explore their semantic similarity:
# interactive(children=(Text(value='king', description='word1'), Text(value='queen', description='word2'), Outpu…
